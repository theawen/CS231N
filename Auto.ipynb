# %% [markdown]
# # Image 1-10000

# %%
user_id0 =[35880634, 1122006, 9145919, 3197898, 7640889, 3424578,
          6491902, 4480830, 7641998, 17810, 1159245, 3079252, 22055974,
          24858906, 10903525, 4429013, 3725576, 33844486, 8968, 1513922,
          5955130, 8006247, 14264762, 24838, 2539925, 3016, 9927548,
          1041507, 25652054, 5429680, 23177484, 349264, 11913860, 4346254,
          9472577, 40958359, 43235973, 7710679, 4801055, 35907, 8187094, 3188698,
          15147502, 32325436, 28552198, 30186793, 29970670, 88258, 33031347, 14480478,
          4091289, 49552835, 10366936, 29573185, 512727, 7038833, 4349073, 3172636,
          2241054, 17332140, 4753177, 9999743, 1114585, 1785711, 6137165, 234389, 9505630,
          8090482, 33590509, 4020461, 851032, 6415776, 8018529, 29592645, 9975772, 5481866,4220066,
           295806,4656482,5494559,2562316,51006201]

# %%
for i in user_id0:
    a = str(i)
    # !python3 pixiv.py $a
# Out:
# Exist Item: 5744
# New Item: 0
#
# Total Image:  0
# Exist Item: 5744
# New Item: 0
#
# Total Image:  0
# Exist Item: 5744
# New Item: 0
#
# Total Image:  0
# Exist Item: 5744
# New Item: 78
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/3197898_81333311_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/3197898_79877103_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/3197898_79324077_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/3197898_79428543_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/3197898_79288098_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/3197898_76580331_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/3197898_74097177_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/3197898_77858041_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/3197898_81773358_p0.jpg ]
# ...

# %%
# delete the images
for i in user_id0:
    # !rm ./PixivImage/$i*
# Out:
# rm: cannot remove './PixivImage/35880634*': No such file or directory
# rm: cannot remove './PixivImage/1122006*': No such file or directory
# rm: cannot remove './PixivImage/9145919*': No such file or directory
# rm: cannot remove './PixivImage/3197898*': No such file or directory
# rm: cannot remove './PixivImage/7640889*': No such file or directory
# rm: cannot remove './PixivImage/3424578*': No such file or directory
# rm: cannot remove './PixivImage/6491902*': No such file or directory
# rm: cannot remove './PixivImage/4480830*': No such file or directory
# rm: cannot remove './PixivImage/7641998*': No such file or directory
# rm: cannot remove './PixivImage/17810*': No such file or directory
# rm: cannot remove './PixivImage/1159245*': No such file or directory
# rm: cannot remove './PixivImage/3079252*': No such file or directory
# rm: cannot remove './PixivImage/22055974*': No such file or directory
# rm: cannot remove './PixivImage/24858906*': No such file or directory
# ...

# %% [markdown]
# # Image 10000-2000

# %%
user_id1 = [273986, 21953098, 1911006, 14709334, 6864949, 71312, 1977715, 24432046, 15711784, 
          13054, 6015940, 21599021, 172228, 15521131, 15034125, 24804871, 11365815, 19098713,
          10453155, 37985868, 1327205, 1566647, 7738363, 1079073, 1023317, 6662895, 853087, 2458,
          2993192, 2063338, 28145748, 4754550, 1894328, 4422621, 20728711, 3569577, 35693, 333556,
          341818, 8993695, 2671042, 4568354, 13804302, 703565, 1055457, 10852879, 32201465, 1391461, 
          5042278, 1055457, 4006137, 564736, 49937, 2356928, 572026, 3572344, 3420822, 14213350,
           19386050, 5224036, 2710689, 3215185,6203904,35279138,12845810, 15976800,16768425,2912049,
           4328506,6108600,24535359,11246082,6491752,35241916,74646,1980643,4742132,40626692, 1796542,
            19236367,25628614,9857110,12817395,35907,20714093,14380777,801146,19440186,295806
           ]

# %%
for i in user_id1:
    a = str(i)
    # !python3 pixiv.py $a
# Out:
# Exist Item: 1
# New Item: 162
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_78510630_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_72212702_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_68231962_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_71930311_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_69604198_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_71717355_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_80793978_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_73040373_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_72562678_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_72300164_p0.jpg ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/273986_78587423_p0.jpg ]
# ...

# %%
# delete the images
for i in user_id1:
    # !rm ./PixivImage/$i*
# Out:
# rm: cannot remove './PixivImage/273986*': No such file or directory
# rm: cannot remove './PixivImage/21953098*': No such file or directory
# rm: cannot remove './PixivImage/1911006*': No such file or directory
# rm: cannot remove './PixivImage/14709334*': No such file or directory
# rm: cannot remove './PixivImage/6864949*': No such file or directory
# rm: cannot remove './PixivImage/71312*': No such file or directory
# rm: cannot remove './PixivImage/1977715*': No such file or directory
# rm: cannot remove './PixivImage/24432046*': No such file or directory
# rm: cannot remove './PixivImage/15711784*': No such file or directory
# rm: cannot remove './PixivImage/13054*': No such file or directory
# rm: cannot remove './PixivImage/6015940*': No such file or directory
# rm: cannot remove './PixivImage/21599021*': No such file or directory
# rm: cannot remove './PixivImage/172228*': No such file or directory
# rm: cannot remove './PixivImage/15521131*': No such file or directory
# ...

# %% [markdown]
# # Image 20000-30000

# %%
user_id2 = [15025460, 765341, 5547917,12669791,40919406,22419458,52311905,18621215,24760818,20722384,
            42501888,5871298,22204209,12450049,13168775,4527763,1018601,19051804,35761559,18977995,
            24865521,15520766,8890590,13746895,5990896,549226,4473872,4925106, 8193760,13475285,32524586,
            7738651,9826340,3529390,7400267,4699098,17194196,16613387,2601440,8549287,21028572,33115141,
            42951056,17893127,2011418,16386606,1616836,2316446,1776737,4636926,38273926,4704903,26348995,
            24346471,10641983,53382942,25362722,29505537,9688381,13442158,5850872,4855514,17723835,7542976,29178735,
            9082563, 43127219,19017901,16273440,42176937,1908623,12834728,444732,23945843,3869665,219621,
            7210261,14983777,1259854,2084226,1443093,1171592,30493160,2746165,20091456,2087091,
            9130455,21330824,7318834,14450835,48979856,45442746,11605692,926687,4952461,5594793,9080785,
            5609647,28889025,2748923,30480490,51215514,5279221,23355982,6269645,27990544,9661136,17582573,
            15980032,2599647,11128987,37216017,18991793,2163630,22003252,46744592,10720265,9152455,19729801,
            2741468,3989209,11190925,2640074,33641486,30772907,2363169,8327064,10914912,2868852,13270255,
            31211466,10847941,3766580,44176925,14559332,14639994,19146146,13937150,27472745,32151651,134377,
            32985219,9560123,23814922,21695879,12898035,17727515,5674458,23261208,22298878,19950472,21390329,
            46737105,12611344,483730,13571851,13885506,4960752,31371435,17202241
           ]

# %%
for i in user_id2:
    a = str(i)
    # !python3 pixiv.py $a
# Out:
# Exist Item: 3217
# New Item: 62
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_75593374_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_75352849_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_76148231_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_75526312_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_75525995_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_75667080_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_75721181_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_75836262_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_80450656_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_76216773_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/15025460_75362838_p0.png ]
# ...

# %%
# delete the images
for i in user_id2:
    # !rm ./PixivImage/$i*

# %% [markdown]
# # Image 30000-40000

# %%
user_id3 = [2003255,12865583,16456626,14490552,28157002,5621747,9930967,54187233,33330729,18997171,
            22246723,112956,30311623,298357,4120726,13959767,28005896,26057814,113939,4578638,
            8089821,5739417,3342095,13929502,25433940,6158947,6948402,3485610,43900269,13739117,
            20973893,14538670,11012664,52506459,10339669,16958947,3393333,3626004,23381353,6748535,
            17140410,3876859,52167704,15447828,4173932,7793770,30129102,25551942,54104360,46208709,
            17579764,44488854,14955867,14988106,20670939,47130765,16984468,40591674,15497823,19478508,
            36696168,4807758,6125168,10013623,36965268,9102371,14879532,14360395,51649196,18217941,
            34946343,49949884,10093111,50013615,17838713,3989209,13885782,44811088,39628892,23285241,
            6907947,5850872,36501589,7651963
           ]

# %%
for i in user_id3:
    a = str(i)
    # !python3 pixiv.py $a
# Out:
# Exist Item: 2
# New Item: 138
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_67110439_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_71599214_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_78051483_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_66814026_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_74458771_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_74935033_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_66675863_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_67340259_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_71286368_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_74342050_p0.png ]
# Pixiv Image: [ OK | /home/kitliu21/crawler/PixivImage/2003255_78911003_p0.png ]
# ...
